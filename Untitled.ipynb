# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
a=pd.read_csv('data.csv')

# %%
a
# Out:
#    Years_Experience  Education_Level  Age  Skills_Rating  Salary
# 0                 1                1   21              4     3.0
# 1                 2                1   22              5     3.8
# 2                 3                2   23              6     4.8
# 3                 4                2   24              6     5.5
# 4                 5                2   25              7     6.2
# 5                 6                3   26              7     7.0
# 6                 7                3   27              8     7.8
# 7                 8                3   28              8     8.6
# 8                 9                3   29              9     9.5
# 9                10                3   30              9    10.3

# %%
x=a[["Years_Experience", "Education_Level", "Age", "Skills_Rating"]]
y = a["Salary"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Predicted Salaries", y_pred)
print("Actual Salaries", list(y_test))
# Out:
# Predicted Salaries [9.46626506 3.87831325]
# Actual Salaries [9.5, 3.8]

# %%
print("Intercept", model.intercept_)
print("Coefficients")
# Out:
# Intercept -5.639759036144595
# Coefficients

# %%
for feature, coef in zip(x.columns, model.coef_):
    print(feature, ":", coef)
# Out:
# Years_Experience : 0.381927710843374
# Education_Level : -0.033734939759036464
# Age : 0.381927710843374
# Skills_Rating : 0.0771084337349399

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])

plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary (Linear Regression)")
plt.show()
